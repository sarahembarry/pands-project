# %% [markdown]
# # Iris Data set

# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier

# %%
# Import csv file from github with the Iris dataset
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv")

# %%
# Open the Iris dataset 
print("The Iris dataset has been imported:")
df
# Out:
# The Iris dataset has been imported:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Get a summary of the variables in the dataset
summary= df.describe(include='all')
# Text message
print("Here is a summary of the Iris dataset:\n")
# Display the summary 
display(summary)
# Out:
# Here is a summary of the Iris dataset:
#         sepal_length  sepal_width  petal_length  petal_width species
# count     150.000000   150.000000    150.000000   150.000000     150
# unique           NaN          NaN           NaN          NaN       3
# top              NaN          NaN           NaN          NaN  setosa
# freq             NaN          NaN           NaN          NaN      50
# mean        5.843333     3.057333      3.758000     1.199333     NaN
# std         0.828066     0.435866      1.765298     0.762238     NaN
# min         4.300000     2.000000      1.000000     0.100000     NaN
# 25%         5.100000     2.800000      1.600000     0.300000     NaN
# 50%         5.800000     3.000000      4.350000     1.300000     NaN
# 75%         6.400000     3.300000      5.100000     1.800000     NaN
# max         7.900000     4.400000      6.900000     2.500000     NaN

# %% [markdown]
# Before performing an analysis, The data quality will be assessed and any missing values identified.<br/>
# It's best practice to thoroughly analyse the dataset for any missing values.

# %%
# Using Pandas
# Check for missing values in the dataset
missing_values = df.isna().sum()
# Display the count of missing values for each column
print(missing_values)
# Text message
print("\nDataset checked for missing values. There are no missing values")
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
#
# Dataset checked for missing values. There are no missing values

# %% [markdown]
# ([Source:cmdlinetips](https://cmdlinetips.com/2020/11/how-to-get-number-of-missing-values-in-each-column-in-pandas/))

# %% [markdown]
# ***

# %% [markdown]
# ## Output a summary of each variable to a single text file.

# %%
# Create a function to write a text file with the summary of the variables
with open("summaryofvariables.txt", "w") as f:
   f.write(summary.to_string())
# Text message
print("A text file with the summary of all variables in the dataset has been generated.")
# Out:
# A text file with the summary of all variables in the dataset has been generated.

# %% [markdown]
# [Source:Stack Overflow](https://stackoverflow.com/questions/57800651/write-multiple-pandas-dataframe-to-the-same-txt-file)

# %% [markdown]
# ---

# %% [markdown]
# ## Output a histogram of each variable to a png file

# %%
# Use Pandas to create a histogram 
df.hist(column='sepal_length', color='blue')
# Use Matplotlib to save the histogram as a png file 
plt.savefig('sepal_length_histogram.png')
# Text message
print("A histogram of 'sepal_length' has been generated and saved as a .png file .")
# Out:
# A histogram of 'sepal_length' has been generated and saved as a .png file .

# %%
# Use Pandas to create a histogram 
df.hist(column='sepal_width', color='blue')
# Use Matplotlib to save the histogram as a png file 
plt.savefig('sepal_width_histogram.png')
# Text message
print("A histogram of 'sepal_width' has been generated and saved as a .png file .")
# Out:
# A histogram of 'sepal_width' has been generated and saved as a .png file .

# %%
# Use Pandas to create a histogram 
df.hist(column='petal_length', color='blue')
# Use Matplotlib to save the histogram as a png file 
plt.savefig('petal_length_histogram.png')
# Text message
print("A histogram of 'petal_length' has been generated and saved as a .png file .")
# Out:
# A histogram of 'petal_length' has been generated and saved as a .png file .

# %%
# Use Pandas to create a histogram 
df.hist(column='petal_width', color='blue')
# Use Matplotlib to save the histogram as a png file 
plt.savefig('petal_width_histogram.png')
# Text message
print("A histogram of 'petal_width' has beeen generated and saved as a .png file .")
# Out:
# A histogram of 'petal_width' has beeen generated and saved as a .png file .

# %% [markdown]
# As the variable 'Species' is a categorical variable rather than a numeric variable like our previous four examples. It is not best suited to being represented as a histogram. <br/>
# Instead a bar chart would is more suitable.<br/>
# [Source:Atlassian](https://www.atlassian.com/data/charts/bar-chart-complete-guide#:~:text=A%20bar%20chart%20is%20used,groups%20compare%20against%20the%20others.)<br/>
# [Source:Statistics Canada](https://www150.statcan.gc.ca/n1/edu/power-pouvoir/ch9/histo/5214822-eng.htm)<br/>

# %%
# Get the counts of each species of Iris in the dataset using Pandas
species_counts = df['species'].value_counts()
# Create and label a bar chart using Matplotlib
plt.bar(species_counts.index,species_counts.values, color='blue')
plt.title('Number of Iris Flowers by Species')
plt.xlabel('Species of Iris Flower')
plt.ylabel('Count of Iris Flowers')
# Save the bar chart as a png file using Matplotlib
plt.savefig('species_barchart.png')
# Text message
print("A barchart of 'species' has been generated and saved as a .png file .")
# Out:
# A barchart of 'species' has been generated and saved as a .png file .

# %% [markdown]
# The dataset contains an equal number of observations for each species of iris.

# %% [markdown]
# [Source:Stack Overflow](https://stackoverflow.com/questions/46411533/how-can-i-save-histogram-plot-in-python)<br/>
# [Source:mode.com](https://mode.com/example-gallery/python_histogram)<br/>
# [Source:Pythonbasics.org](https://pythonbasics.org/matplotlib-bar-chart/)

# %% [markdown]
# ---

# %% [markdown]
# ## Create a matrix to show the correlation of all variables

# %%
# Using Pandas
# Create a dataframe of only the numeric colums in the dataset
numeric_df = df.select_dtypes(include='number')
# Create a correlation matrix of the dataframe
correlation_matrix = numeric_df.corr()
# Text message
print("Here is a matrix of the correlation between the numeric variables in the datset:\n")
# Display correlation matrix
print(correlation_matrix)
# Out:
# Here is a matrix of the correlation between the numeric variables in the datset:
#
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# The variables `petal_length` and `petal_width` show the highest positive correlation, while `petal_length` and `sepal_width` display the most negative correlation.

# %% [markdown]
# [Source:geeksforgeeks.org](https://www.geeksforgeeks.org/how-to-create-a-correlation-matrix-using-pandas/)<br/>
# [Source:note.nkmk.me](https://note.nkmk.me/en/python-pandas-select-dtypes/)

# %% [markdown]
# ---

# %% [markdown]
# ## Output a box plot for each feature by species of Iris

# %%
# Text message
print("Boxplots for each numeric variable by species have been generated:\n")
# Create figure and set size
plt.figure(figsize=(9, 6))

# Use Matplotlib to create a subplot for this variable
plt.subplot(2, 2, 1)
# Use Seabourn to create a boxplot of sepal length by species
sns.boxplot(x='species', y='sepal_length', data=df)
# Set the title of the subplot
plt.title('Sepal Length (cm)')

# Use Matplotlib to create a subplot for this variable
plt.subplot(2, 2, 2)
# Use Seabourn to create a boxplot of sepal width by species
sns.boxplot(x='species', y='sepal_width', data=df)
# Set the title of the subplot
plt.title('Sepal Width (cm)')

# Use Matplotlib to create a subplot for this variable
plt.subplot(2, 2, 3)
# Use Seabourn to create a boxplot of petal length by species
sns.boxplot(x='species', y='petal_length', data=df)
# Set the title of the subplot
plt.title('Petal Length (cm)')

# Use Matplotlib to create a subplot for this variable
plt.subplot(2, 2, 4)
# Use Seabourn to create a boxplot of petal width by species
sns.boxplot(x='species', y='petal_width', data=df)
# Set the title of the subplot
plt.title('Petal Width (cm)')

# use Matplotlib to adjust layout
plt.tight_layout()
# Display boxplots
plt.show()
# Out:
# Boxplots for each numeric variable by species have been generated:

# %% [markdown]
# [Source: Hfahmida Data Science and Business Analytics:TRIDS](https://medium.com/@hfahmida/eda-for-iris-dataset-with-boxplots-violin-plots-heatmap-pairwise-plots-535275b4c2a0)<br/>
# [Source: BEN HAMNER ](https://www.kaggle.com/code/benhamner/python-data-visualizations)<br/>

# %% [markdown]
# Based on the visualisation above:<br/>
# - Virginica irises generally have the longest `sepal_length` and `petal_length`, as well as the widest `petal_width`.
# - Setosa Irises generally display the widest `sepal_width`, but the shortest `sepal_length`, `petal_length`, and `petal_width`.
# - Versicolor irises fall between the other two species in terms of `sepal_length` ,`petal_length` and `petal width`, with the lowest `sepal_width` amoung the 3 species.<br/>
#
# While each species of Iris has outliers it is clear to see that generally each species has it's own characteristics.

# %% [markdown]
# ---

# %% [markdown]
# ## Output a scatter plot of each pair of variables

# %% [markdown]
# Below, the scatter plots illustrate how each variable correlates across different species.

# %% [markdown]
# Please be advised: Due to the plot's size, a warning has been generated regarding the layout changing to a 'tight layout'. As this does not compromise the integrity of the plot, This warning will be filtered out.

# %%
# Use Warnings to filter out tight layout warnings
warnings.filterwarnings("ignore", message="The figure layout has changed to tight")

# %%
# Text message
print("A scatterplot of the correlation of numeric variables by species has been generated:\n")
# Use Seabourn to create pairplot with hue='species' to visualize correlations 
sns.pairplot(df, hue='species')
# Use Matplotlib to display the pairplot
plt.show()
# Out:
# A scatterplot of the correlation of numeric variables by species has been generated:

# %% [markdown]
# Based on the visualisation above:<br/>
#
# - Among all variables, `petal_length` and `petal_width` show the strongest correlation, particularly noticeable in Versicolor and Virginica species. Setosa also displays this correlation, but its data points mostly cluster towards the bottom-left of the chart.
# - There's also a positive correlation between `petal_width` and `sepal_length`, though not as strong. This correlation is generally stronger in Versicolor and Virginica species, but with more outliers.

# %% [markdown]
# [Source:geeksforgeeks.org](https://www.geeksforgeeks.org/python-seaborn-pairplot-method/)

# %% [markdown]
# ---

# %% [markdown]
# ## Output an interactive scatter plot of  of petal_length and petal_width

# %% [markdown]
# Below is a closer look at the correlation between petal_lenth and petal_width by species.

# %%
# Text message
print("A interactive scatterplot of 'petal length' and 'petal width' has been generated:\n")
# Use Plotly Express to create an interactive scatter plot with different colours and symbols for each species.
fig = px.scatter(df, x="petal_length", y="petal_width",
                 color="species",
                 symbol="species",  
                 hover_data=['petal_length', 'petal_width'])
fig.show()
# Out:
# A interactive scatterplot of 'petal length' and 'petal width' has been generated:

# %% [markdown]
# [Source:geeksforgeeks](https://www.geeksforgeeks.org/scatter-plot-using-plotly-in-python/)<br/>

# %% [markdown]
# ## Use machine learning to predict Iris species

# %% [markdown]
# ---

# %% [markdown]
# ### Features and target. Training and test data

# %%
# Create a dataframe with the 'features'
x = df[['sepal_length', 'sepal_width' ,'petal_length','petal_width']]
# Create a data frame with the 'target'
y = df['species']

# Split the data into training and testing sets for both 'features' and 'target'
# test_size = sets the percent of data to be used for testing (remaining percentage is used for training)
# random_state = sets the seed for the random number generator for used for splitting the data into training and testing sets.
x_train, x_test, y_train,y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# Logistic regression predicts the probability of an instance belonging to a class. It analyses the relationship between two different factors to determine this.<br/>
# ([Source:geeksforgeeks](https://www.geeksforgeeks.org/understanding-logistic-regression/))<br/><br/>
# Here, logistic regression will be used to predict Iris species based on their features. The model will analyse the relationship between the numeric variables (features) and the species (target) to determine which species or 'class' each instance belongs to.

# %%
# Initialise the logicstic regression model from sklearn
log_reg_model= LogisticRegression()
# Apply the model to the training data
log_reg_model.fit(x_train,y_train)
# Use the model to make predictions on the x_test data
log_reg_predicitons = log_reg_model.predict(x_test)

# %% [markdown]
# [Source:Johar Khan](https://www.youtube.com/watch?v=2HfJVdj3SpM)<br/>
# [Source:Rahul Raj Pandey](https://www.kaggle.com/code/rahulrajpandey31/logistic-regression-from-scratch-iris-data-set)<br/>
# [Source:Datacamp](https://www.datacamp.com/tutorial/understanding-logistic-regression-python)

# %%
# Text message
print("A logistic regression model has been trained to predict Iris species based on features using the dataset. Here are the results:\n")
# Print classification report
# This tells us the values in the target variable and how well the model presicted them
print(classification_report(y_test,log_reg_predicitons))
# Out:
# A logistic regression model has been trained to predict Iris species based on features using the dataset. Here are the results:
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       1.00      1.00      1.00         9
#    virginica       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# [Source:Johar Khan](https://www.youtube.com/watch?v=2HfJVdj3SpM)<br/>
# [Source:Rahul Raj Pandey](https://www.kaggle.com/code/rahulrajpandey31/logistic-regression-from-scratch-iris-data-set)<br/>
# [Source:Datacamp](https://www.datacamp.com/tutorial/understanding-logistic-regression-python)

# %% [markdown]
# The classification report evaluates the model's accuracy in predicting target values. Based on current model set up it shows 100%. However, when changing the 'random_state', the F1 scores for 'virginica' dropped to as low as 88%, and for 'versicolor' dropped to as low as 91%. Setosa stayed consistent at 100% accuracy. Therefore, the training versus testing data split significantly affects model accuracy

# %%
# Text message
print("A Setosa entry was selected, and its features were input into the logistic regression model. Here is the Iris species predicted by the model:")

# Create a dictionary containing the 'features'
# Pick a random plant from the data set and add in the values (5.0	3.6	1.4	0.2	setosa)
log_reg_test_plant = {
    'sepal_length': 5.0,
    'sepal_width': 3.6 ,
    'petal_length': 1.4 ,
    'petal_width': 0.2 ,
}
# Create a dataframe from the dictionary
log_reg_plant_df = pd.DataFrame([log_reg_test_plant])
# Use the model and 'predict method' to predict the species Iris
log_reg_model.predict(log_reg_plant_df)
# Out:
# A Setosa entry was selected, and its features were input into the logistic regression model. Here is the Iris species predicted by the model:
# array(['setosa'], dtype=object)

# %%
# Text message
print("The logistic regression model has predicted correctly")
# Out:
# The logistic regression model has predicted correctly

# %% [markdown]
# [Source:Johar Khan](https://www.youtube.com/watch?v=2HfJVdj3SpM)<br/>

# %% [markdown]
# ### K-nearest neighbor
# K-nearest neighbor (KNN) predicts what class an instance belongs to by looking at its closest neighbors. It assumes that things with similar features are in the same class.<br/>
# ([Source:Zilliz](https://zilliz.com/blog/k-nearest-neighbor-algorithm-for-machine-learning))<br/>
# ([Source:javatpoint.com](https://www.javatpoint.com/k-nearest-neighbor-algorithm-for-machine-learning))<br/>
#
# Here, the KNN will use the numeric variables(features) of each species(class) to determine what species an unknown instance of Iris belongs to.

# %%
# Text message
print("A K Nearest Neighbor model has been trained to predict Iris species based on features using the dataset. Here are the results:\n")



# Initialise the Knn model from sklearn
knn_model = KNeighborsClassifier(n_neighbors=3)
# Apply the model to the training data
knn_model.fit(x_train, y_train)
# Use the model to make predictions on the x_test data
knn_predictions = knn_model.predict(x_test)
# Out:
# A K Nearest Neighbors model has been trained to predict Iris species based on features using the dataset. Here are the results:

# %%
# Evaluate the model
print(classification_report(y_test, knn_predictions))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       1.00      1.00      1.00         9
#    virginica       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# The classification report assesses the model's accuracy, which is currently at 100%. However, adjusting the 'n_neighbors' parameter affects F1 scores. When 'n_neighbors' exceeds 45, F1 scores for 'virginica' and 'versicolor' drop below 100%. Setting 'n_neighbors' to 78 results in a virginica F1 score of 0. The optimal 'n_neighbors' value for this model is below 45.

# %%
# Text message
print("A Virginica entry was selected, and its features were input into the K-nearest neighbour model. Here is the Iris species predicted by the model:")
# Create a dictionary containing the feature variablies 
# Pick a random plant from the data set and add in the values (5.9,3.0,5.1,1.8	- virginica)
knn_plant = {
    'sepal_length': 5.9,
    'sepal_width': 3.0 ,
    'petal_length': 5.1 ,
    'petal_width': 1.8 ,
}
# Create a dataframe from the dictionary
knn_df = pd.DataFrame([knn_plant])
# Use the model and predict method to predict the species of the plan using the dictionary data
knn_model.predict(knn_df)
# Out:
# A Virginica entry was selected, and its features were input into the K-nearest neighbours model. Here is the Iris species predicted by the model:
# array(['virginica'], dtype=object)

# %% [markdown]
# [Source:AI with AI](https://www.youtube.com/watch?v=KvYGJt3cTj4)<br/>
# [Source:S.Sreenivasulu](https://www.kaggle.com/code/susree64/k-nearest-neighbor-with-iris-data-set)<br/>

# %%
# Text message
print("The k-nearest neighbor model has predicted correctly")
# Out:
# The k-nearest neighbors model has predicted correctly

# %% [markdown]
# ---
